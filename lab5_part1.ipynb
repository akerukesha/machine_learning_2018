# %% [markdown]
# # Lab 3. Pandas, метод ближайших соседей и решающие деревья.

# %% [markdown]
# Name: Okapova Akerke
#
# Student ID: 15BD02047
#
# Email: okapova.akerke@gmail.com

# %% [markdown]
# ## Часть 1: Pandas

# %% [markdown]
# #### Ответьте на вопросы о данных по авиарейсам в США.
#
# Данные: http://stat-computing.org/dataexpo/2009/2008.csv.bz2
# (обратите внимание, что распаковывать этот файл не обязательно — функция `pandas.read_csv` умеет читать из архивов автоматически)
#
# Описание: http://stat-computing.org/dataexpo/2009/the-data.html

# %%
import numpy as np
import pandas as pd
import time

# %%
data = pd.read_csv("2008.csv.bz2")
data.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  7009728.0  7.009728e+06  7.009728e+06  7.009728e+06  6.873482e+06
# mean      2008.0  6.375130e+00  1.572801e+01  3.924182e+00  1.333830e+03
# std          0.0  3.406737e+00  8.797068e+00  1.988259e+00  4.780689e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  9.280000e+02
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.325000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  1.728000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  7.009728e+06  6.858079e+06  7.009728e+06  7.009728e+06
# mean   1.326086e+03  1.481258e+03  1.494801e+03  2.224200e+03
# std    4.642509e+02  5.052251e+02  4.826728e+02  1.961716e+03
# ...

# %% [markdown]
# 1. Какая из причин отмены рейса (`CancellationCode`) была самой частой? (расшифровки кодов можно найти в описании данных)

# %%
data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        2225            WN        335        ...            4.0      8.0
# 1        1000            WN       3231        ...            5.0     10.0
# 2         750            WN        448        ...            3.0     17.0
# 3        1100            WN       1746        ...            3.0      7.0
# 4        1925            WN       3920        ...            3.0     10.0
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
np.argmax(data.CancellationCode.value_counts())
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# 'B'

# %% [markdown]
# 2. Найдите среднее, минимальное и максимальное расстояние, пройденное самолетом.

# %%
data['Distance'].mean()
# Out:
# 726.3870294253928

# %%
data['Distance'].min()
# Out:
# 11

# %%
data['Distance'].max()
# Out:
# 4962

# %% [markdown]
# 3. Не выглядит ли подозрительным минимальное пройденное расстояние? В какие дни и на каких рейсах оно было? Какое расстояние было пройдено этими же рейсами в другие дни?

# %%
mindata = data[data.Distance == 11]
print("DATA")
print(mindata)
print("FLIGHT DATA")
print (mindata[['Year','Month','DayofMonth','DayOfWeek','FlightNum','UniqueCarrier']])

data4988 = data[data.FlightNum == 4988]
data5572 = data[data.FlightNum == 5572]
print("FLIGHT 4988")
print(data4988[['Year','Month','DayofMonth','DayOfWeek','FlightNum','UniqueCarrier', 'Distance']])
print("FLIGHT 5572")
print(data5572[['Year','Month','DayofMonth','DayOfWeek','FlightNum','UniqueCarrier', 'Distance']])
# Out:
# DATA
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 2547298  2008      5          15          4   2037.0        1800   2125.0
# 4392215  2008      8          10          7   1315.0        1220   1415.0
#
#          CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  \
# 2547298        1900            OH       4988        ...           10.0
# 4392215        1320            OH       5572        ...            8.0
#
#          TaxiOut  Cancelled  CancellationCode  Diverted  CarrierDelay  \
# 2547298      7.0          0               NaN         0         145.0
# 4392215     38.0          0               NaN         0          55.0
#
#         WeatherDelay NASDelay  SecurityDelay  LateAircraftDelay
# 2547298          0.0      0.0            0.0                0.0
# 4392215          0.0      0.0            0.0                0.0
#
# [2 rows x 29 columns]
# FLIGHT DATA
#          Year  Month  DayofMonth  DayOfWeek  FlightNum UniqueCarrier
# ...

# %% [markdown]
# 4. Из какого аэропорта было произведено больше всего вылетов? В каком городе он находится?

# %%
np.argmax(data.Origin.value_counts())
# Out:
# 'ATL'

# %% [markdown]
# 5. Найдите для каждого аэропорта среднее время полета (`AirTime`) по всем вылетевшим из него рейсам. Какой аэропорт имеет наибольшее значение этого показателя?

# %%
print(data.groupby('Origin').AirTime.mean())
print(np.argmax(data.groupby('Origin').AirTime.mean()))
# Out:
# Origin
# ABE     89.057518
# ABI     36.789977
# ABQ     91.657166
# ABY     35.379759
# ACK     50.692124
# ACT     29.875977
# ACV     58.850658
# ACY    108.848214
# ADK    151.423913
# ADQ     41.987934
# AEX     68.543556
# AGS     36.933814
# AKN     37.321429
# ALB    101.860527
# ALO     36.373134
# AMA     56.196001
# ANC    156.163749
# ASE     48.307996
# ATL     93.320419
# ATW     50.696326
# AUS    101.266600
# AVL     69.899021
# AVP     94.665204
# AZO     34.846602
# BDL    118.701612
# BET     57.597815
# BFL     64.024511
# BGM     66.582260
# BGR     90.211095
# BHM     82.290713
#           ...
# SPS     29.490040
# SRQ    103.083807
# STL     99.294409
# STT    168.681929
# STX    168.101176
# SUN     48.221851
# SUX     44.918919
# SWF    132.768826
# SYR     84.524087
# TEX     93.124183
# TLH     59.293080
# TOL     48.295047
# TPA    117.917963
# TRI     47.871046
# TUL     80.876802
# TUP     42.900000
# TUS     92.801864
# TVC     49.328770
# ...

# %% [markdown]
# 6. Найдите аэропорт, у которого наибольшая доля задержанных (`DepDelay > 0`) рейсов. Исключите при этом из рассмотрения аэропорты, из которых было отправлено меньше 1000 рейсов (используйте функцию `filter` после `groupby`).

# %%
grouped = data.groupby('Origin').filter(lambda x: len(x)>=1000)
filtered = grouped.groupby('Origin')
tmp = filtered.agg(lambda x: sum(x['DepDelay']>0)/float(len(x['DepDelay'])))['DepDelay']
max(tmp.iteritems(), key = lambda x: x[1])
# Out:
# ('DAL', 0.5786418928942293)

# %% [markdown]
# Здесь вы можете поделиться своими мыслями о задании.

# %% [markdown]
# *Ну, сложновато было, да...*

# %% [markdown]
# А здесь вставьте смешную картинку.

# %% [markdown]
# ![](https://i.redd.it/077bsten3fx01.jpg)

# %% [markdown]
# А здесь посоветуйте преподавателям хороший фильм или сериал.

# %% [markdown]
# [Loving Vincent](https://www.imdb.com/title/tt3262342/)
#
# [Lucky Number Slevin](https://www.imdb.com/title/tt0425210/)
#
# [Arrival](https://www.imdb.com/title/tt2543164/)
#
# [A Quiet Place](https://www.imdb.com/title/tt6644200/)
#
# [Nocturnal Animals](https://www.imdb.com/title/tt4550098/)
